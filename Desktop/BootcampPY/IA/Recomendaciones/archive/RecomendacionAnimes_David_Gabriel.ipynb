# %%
import numpy as np 
import pandas as pd
import html
from tabulate import tabulate
from scipy.sparse import csr_matrix

# %%
#El encoding="utf-8" lo que hace es controlar los caracteres raros estilo ñ
anime_cols = ['anime_id', 'name', 'genre', 'type', 'episodes', 'rating', 'members']
ratings_cols = ['user_id', 'anime_id', 'rating']

anime = pd.read_csv('C:\\Users\\Gabriel\\datos\\anime.csv',names=anime_cols, header=0, encoding="utf-8")
ratings = pd.read_csv('C:\\Users\\Gabriel\\datos\\rating.csv',names=ratings_cols, header=0, encoding="utf-8")

# %%
anime.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
#El html lo que hace es por si haya algun caracter raro pues lo ponga de forma normal
anime['name'] = anime['name'].apply(html.unescape)

# %%
ratings.head()
# Out:
#    user_id  anime_id  rating
# 0        1        20      -1
# 1        1        24      -1
# 2        1        79      -1
# 3        1       226      -1
# 4        1       241      -1

# %% [markdown]
# ## Limpieza de datos y cambio de nombres

# %%
#Se sabe que alguno de estos no los usamos pero los limpiamos y arregalos por si acaso se desea utilizar a futuro
anime['episodes'] = anime['episodes'].replace('Unknown', np.nan).astype(float)
anime['genre'] =  anime['genre'].fillna('Unknown')
anime['rating'] = anime['rating'].fillna(anime['rating'].mean())
anime['type'] = anime['type'].fillna('Unknown')

#Eliminamos y/o tratamos los que tengan alguna columna vacia o en otras diferente (ejemplo un caso de un anime que parte de sus datos estaba en la B del csv)
anime = anime.dropna(subset=['episodes', 'rating', 'type', 'genre'])
ratings = ratings[ratings['rating'] != -1]
ratings = ratings.dropna(subset=['user_id', 'anime_id', 'rating'])

# %%
#Cambio de nombres para tenerlos mas claros
ratings = ratings.rename(columns={"rating": "user_rating"})
anime = anime.rename(columns={"rating": "anime_rating"})

# %%
ratings_with_name = ratings.merge(anime[['anime_id', 'name']], on='anime_id', how='inner')
#Estas lineas cambian el tipo de datos de las columnas introducidas a category
#Los category ocupan menos espacio que object o int
ratings_with_name['name'] = ratings_with_name['name'].astype('category')
ratings_with_name['user_id'] = ratings_with_name['user_id'].astype('category')
ratings_with_name.head()
# Out:
#   user_id  anime_id  user_rating                    name
# 0       1      8074           10  Highschool of the Dead
# 1       1     11617           10         High School DxD
# 2       1     11757           10        Sword Art Online
# 3       1     15451           10     High School DxD New
# 4       2     11771           10        Kuroko no Basket

# %%
# Filtrar por los animes más puntuados
anime_counts = ratings_with_name['name'].value_counts() #Cuenta de calificación por anime
popular_animes = anime_counts[anime_counts > 400].index #Filtrado de mas de 400 Calificaciones

filtered = ratings_with_name[ratings_with_name['name'].isin(popular_animes)] #Filtrado para solamente quedarse los populares y eliminar el resto

ratings_pivot = filtered.pivot_table(
    index='user_id',
    columns='name',
    values='user_rating',
    aggfunc='mean',
    observed=True
).astype('float32')

ratings_pivot.head()
# Out:
# name     "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi  "Bungaku Shoujo" Memoire  \
# user_id
# 1                                              NaN                       NaN
# 2                                              NaN                       NaN
# 3                                              NaN                       NaN
# 5                                              NaN                       NaN
# 7                                              NaN                       NaN
#
# name     "Bungaku Shoujo" Movie  .hack//G.U. Returner  .hack//G.U. Trilogy  \
# user_id
# 1                           NaN                   NaN                  NaN
# 2                           NaN                   NaN                  NaN
# 3                           NaN                   NaN                  NaN
# 5                           NaN                   NaN                  NaN
# 7                           NaN                   NaN                  NaN
#
# name     .hack//Gift  .hack//Intermezzo  .hack//Liminality  .hack//Quantum  \
# user_id
# 1                NaN                NaN                NaN             NaN
# 2                NaN                NaN                NaN             NaN
# 3                NaN                NaN                NaN             NaN
# 5                NaN                NaN                NaN             NaN
# 7                NaN                NaN                NaN             NaN
#
# name     .hack//Roots  ...  ef: A Tale of Melodies.  \
# user_id                ...
# 1                 NaN  ...                      NaN
# 2                 NaN  ...                      NaN
# 3                 NaN  ...                      NaN
# 5                 NaN  ...                      NaN
# 7                 NaN  ...                      NaN
#
# name     ef: A Tale of Melodies. - Prologue  ef: A Tale of Memories.  \
# user_id
# 1                                       NaN                      NaN
# 2                                       NaN                      NaN
# 3                                       NaN                      NaN
# 5                                       NaN                      NaN
# 7                                       NaN                      NaN
#
# name     ef: A Tale of Memories. - Prologue  s.CRY.ed  xxxHOLiC  xxxHOLiC Kei  \
# user_id
# 1                                       NaN       NaN       NaN           NaN
# 2                                       NaN       NaN       NaN           NaN
# 3                                       NaN       NaN       NaN           NaN
# 5                                       NaN       NaN       2.0           NaN
# 7                                       NaN       NaN       NaN           NaN
#
# name     xxxHOLiC Movie: Manatsu no Yoru no Yume  xxxHOLiC Rou  \
# user_id
# 1                                            NaN           NaN
# 2                                            NaN           NaN
# 3                                            NaN           NaN
# 5                                            NaN           NaN
# 7                                            NaN           NaN
#
# name     xxxHOLiC Shunmuki
# user_id
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 5                      NaN
# 7                      NaN
#
# [5 rows x 2466 columns]

# %%
corrMatrix = ratings_pivot.corr(method='pearson', min_periods=250) #Minimo 250 que evaluaron los animes
corrMatrix.head()
# Out:
# name                                       "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi  \
# name
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi                                   1.000000
# "Bungaku Shoujo" Memoire                                                    0.744635
# "Bungaku Shoujo" Movie                                                      0.637777
# .hack//G.U. Returner                                                             NaN
# .hack//G.U. Trilogy                                                              NaN
#
# name                                       "Bungaku Shoujo" Memoire  \
# name
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi                  0.744635
# "Bungaku Shoujo" Memoire                                   1.000000
# "Bungaku Shoujo" Movie                                     0.765973
# .hack//G.U. Returner                                            NaN
# .hack//G.U. Trilogy                                             NaN
#
# name                                       "Bungaku Shoujo" Movie  \
# name
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi                0.637777
# "Bungaku Shoujo" Memoire                                 0.765973
# "Bungaku Shoujo" Movie                                   1.000000
# .hack//G.U. Returner                                          NaN
# .hack//G.U. Trilogy                                           NaN
#
# name                                       .hack//G.U. Returner  \
# name
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi                   NaN
# "Bungaku Shoujo" Memoire                                    NaN
# "Bungaku Shoujo" Movie                                      NaN
# .hack//G.U. Returner                                   1.000000
# .hack//G.U. Trilogy                                    0.698365
#
# name                                       .hack//G.U. Trilogy  .hack//Gift  \
# name
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi                  NaN          NaN
# "Bungaku Shoujo" Memoire                                   NaN          NaN
# "Bungaku Shoujo" Movie                                     NaN          NaN
# .hack//G.U. Returner                                  0.698365     0.617314
# .hack//G.U. Trilogy                                   1.000000     0.552365
#
# name                                       .hack//Intermezzo  \
# name
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi                NaN
# "Bungaku Shoujo" Memoire                                 NaN
# "Bungaku Shoujo" Movie                                   NaN
# .hack//G.U. Returner                                0.673917
# .hack//G.U. Trilogy                                 0.554392
#
# name                                       .hack//Liminality  .hack//Quantum  \
# name
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi                NaN             NaN
# "Bungaku Shoujo" Memoire                                 NaN             NaN
# "Bungaku Shoujo" Movie                                   NaN             NaN
# .hack//G.U. Returner                                0.598627             NaN
# .hack//G.U. Trilogy                                 0.512949        0.471152
#
# name                                       .hack//Roots  ...  \
# name                                                     ...
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi           NaN  ...
# "Bungaku Shoujo" Memoire                            NaN  ...
# "Bungaku Shoujo" Movie                              NaN  ...
# .hack//G.U. Returner                           0.665746  ...
# .hack//G.U. Trilogy                            0.596812  ...
#
# name                                       ef: A Tale of Melodies.  \
# name
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi                      NaN
# "Bungaku Shoujo" Memoire                                  0.402413
# "Bungaku Shoujo" Movie                                    0.365946
# .hack//G.U. Returner                                           NaN
# .hack//G.U. Trilogy                                            NaN
#
# name                                       ef: A Tale of Melodies. - Prologue  \
# name
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi                                 NaN
# "Bungaku Shoujo" Memoire                                                  NaN
# "Bungaku Shoujo" Movie                                                    NaN
# .hack//G.U. Returner                                                      NaN
# .hack//G.U. Trilogy                                                       NaN
#
# name                                       ef: A Tale of Memories.  \
# name
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi                 0.334864
# "Bungaku Shoujo" Memoire                                  0.351132
# "Bungaku Shoujo" Movie                                    0.388724
# .hack//G.U. Returner                                           NaN
# .hack//G.U. Trilogy                                            NaN
#
# name                                       ef: A Tale of Memories. - Prologue  \
# name
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi                                 NaN
# "Bungaku Shoujo" Memoire                                                  NaN
# "Bungaku Shoujo" Movie                                                    NaN
# .hack//G.U. Returner                                                      NaN
# .hack//G.U. Trilogy                                                       NaN
#
# name                                       s.CRY.ed  xxxHOLiC  xxxHOLiC Kei  \
# name
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi       NaN       NaN           NaN
# "Bungaku Shoujo" Memoire                        NaN       NaN           NaN
# "Bungaku Shoujo" Movie                          NaN  0.232156      0.335691
# .hack//G.U. Returner                            NaN       NaN           NaN
# .hack//G.U. Trilogy                             NaN       NaN           NaN
#
# name                                       xxxHOLiC Movie: Manatsu no Yoru no Yume  \
# name
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi                                      NaN
# "Bungaku Shoujo" Memoire                                                       NaN
# "Bungaku Shoujo" Movie                                                         NaN
# .hack//G.U. Returner                                                           NaN
# .hack//G.U. Trilogy                                                            NaN
#
# name                                       xxxHOLiC Rou  xxxHOLiC Shunmuki
# name
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi           NaN                NaN
# "Bungaku Shoujo" Memoire                            NaN                NaN
# "Bungaku Shoujo" Movie                              NaN                NaN
# .hack//G.U. Returner                                NaN                NaN
# .hack//G.U. Trilogy                                 NaN                NaN
#
# [5 rows x 2466 columns]

# %%
#Usuario de prueba 
user_test_ratings = {
    "Hunter x Hunter": 10,
    "School Days": 1
}

#Verificar que esos animes existen en la matriz de correlación
available_animes = [anime for anime in user_test_ratings.keys() if anime in corrMatrix.columns]
if not available_animes:
    raise ValueError("Ninguno de los animes especificados está en la matriz de correlación.")

#Convertir a serie con las calificaciones del usuario de prueba
myRatings = pd.Series({anime: user_test_ratings[anime] for anime in available_animes})
print("Calificaciones del usuario de prueba:")
print(myRatings)

#Generar candidatos de recomendación
simCandidates = pd.Series(dtype='float64')

for anime_name, rating_value in myRatings.items():
    print(f"\nAñadiendo animes similares a {anime_name}...")
    #Recuperar las similitudes del anime actual
    sims = corrMatrix[anime_name].dropna()
    #Escalar la similaridad multiplicando la correlación por la calificación de la persona
    sims = sims.map(lambda x: x * rating_value)
    #Agregar al conjunto de candidatos
    simCandidates = pd.concat([simCandidates, sims])

#Agrupar y ordenar resultados
print("\nOrdenando recomendaciones...")
simCandidates = simCandidates.groupby(simCandidates.index).sum() #Agrupamos para sumar puntaje por que salen repetidos
simCandidates.sort_values(inplace=True, ascending=False)

#Eliminar los animes ya vistos/repetidos
filteredSims = simCandidates.drop(myRatings.index, errors='ignore')

print("\nTop 50 recomendaciones para el usuario de prueba:")
print(filteredSims.head(50))
# Out:
# Calificaciones del usuario de prueba:
# Hunter x Hunter    10
# School Days         1
# dtype: int64
#
# Añadiendo animes similares a Hunter x Hunter...
#
# Añadiendo animes similares a School Days...
#
# Ordenando recomendaciones...
#
# Top 50 recomendaciones para el usuario de prueba:
# Hunter x Hunter OVA                                                        7.561694
# Hunter x Hunter: Greed Island                                              6.924545
# Hunter x Hunter: Greed Island Final                                        6.800874
# Yowamushi Pedal: Grande Road                                               5.074912
# Hajime no Ippo: Champion Road                                              4.951404
# Prince of Tennis: The National Tournament Semifinals                       4.747973
# Yakitate!! Japan                                                           4.672146
# Rekka no Honoo                                                             4.572643
# Ragnarök the Animation                                                     4.546601
# Sengoku Basara Two                                                         4.397920
# Hajime no Ippo: Mashiba vs. Kimura                                         4.391618
# Yuu☆Yuu☆Hakusho                                                            4.390202
# The Law of Ueki                                                            4.388086
# Rental Magica                                                              4.351683
# Hajime no Ippo: New Challenger                                             4.343229
# Rozen Maiden                                                               4.341661
# Hunter x Hunter (2011)                                                     4.298848
# Mayoi Neko Overrun!                                                        4.287127
# Mobile Suit Gundam Seed Destiny                                            4.284041
# Kami nomi zo Shiru Sekai: Tenri-hen                                        4.280408
# Kamisama Dolls                                                             4.250682
# Saiunkoku Monogatari                                                       4.239329
# Kuroko no Basket: Tip Off                                                  4.232504
# Hajime no Ippo: Rising                                                     4.216045
# Saint Seiya: The Lost Canvas - Meiou Shinwa 2                              4.210327
# Kyou kara Maou!                                                            4.197604
# GetBackers                                                                 4.186212
# Eyeshield 21                                                               4.178573
# Prince of Tennis                                                           4.159080
# Katekyo Hitman Reborn!                                                     4.136237
# Hikaru no Go                                                               4.127564
# Mobile Suit Gundam Wing                                                    4.120048
# Kodomo no Jikan (TV)                                                       4.111951
# Kekkaishi                                                                  4.109596
# Slam Dunk                                                                  4.101969
# Ao no Exorcist: Kuro no Iede                                               4.090150
# Groove Adventure Rave                                                      4.078393
# Shakugan no Shana Movie                                                    4.066889
# Kaleido Star                                                               4.057122
# Boku wa Tomodachi ga Sukunai: Relay Shousetsu wa Ketsumatsu ga Hanpanai    4.050114
# Initial D Third Stage                                                      4.002389
# Gun x Sword                                                                3.990013
# Spiral: Suiri no Kizuna                                                    3.988931
# Gensoumaden Saiyuuki                                                       3.979611
# Prince of Tennis: The National Tournament Finals                           3.979427
# Inukami!                                                                   3.976947
# World Destruction: Sekai Bokumetsu no Rokunin                              3.966569
# Ookiku Furikabutte: Natsu no Taikai-hen                                    3.962120
# Naruto Shippuuden: Shippuu! "Konoha Gakuen" Den                            3.943598
# Dragon Crisis!                                                             3.941857
# dtype: float64
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_19796\150212671.py:27: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   simCandidates = pd.concat([simCandidates, sims])
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_19796\150212671.py:31: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   simCandidates = simCandidates.groupby(simCandidates.index).sum() #Agrupamos para sumar puntaje por que salen repetidos
